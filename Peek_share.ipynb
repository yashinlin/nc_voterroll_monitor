# %%
from pathlib import Path
import pandas as pd

path = "/home/yubuntu/nc_voterroll_monitor/data/ncvoter_Statewide 2026.08.31/ncvoter_Statewide.txt"

df = pd.read_csv(path,
    nrows=20,
    sep='\t',  # Tab delimiter
    quotechar='"'
)
print(df.head())

# %%
df.info()

# %%
df.describe()

# %%
df.columns

# %%
from pathlib import Path
downloads = Path("/mnt/c/Users/yashi/Downloads")
output_file = downloads/"ncvoter_sample_20rows.csv"

# %%
df.to_csv(output_file, index=False)
print(f"Saved to: {output_file}")
